# %% [markdown]
# # Binance PM Manual Console

# %%
from exli.enum_type import Exchange, AccountType, InstType, InstStatus
from exli.binanceunified.rest import BinanceUnifiedRestClient
from exli.binance.rest import BinanceSpotRestClient
from exli.binance.wrapper import BinanceRestWrapper
from exli.get_client import get_rest_client, get_rest_wrapper
from exli.inst_mngr import InstrumentManager, Instrument
from exli.utils import Cast, quantize

import pandas as pd
import json
import asyncio
from datetime import datetime
from decimal import Decimal
import random
import arrow
from pprint import pprint

# %%
console_acct = "bntest01"

scli: BinanceSpotRestClient = get_rest_client(
    Exchange.BINANCE,
    InstType.SP,
    account=console_acct,
)
pcli: BinanceUnifiedRestClient = get_rest_client(
    Exchange.BINANCEUNIFIED,
    InstType.LPS,
    account=console_acct,
)
pwpr_sp: BinanceRestWrapper = get_rest_wrapper(
    exchange=Exchange.BINANCEUNIFIED,
    acct_type=AccountType.MARGIN,
    account=console_acct,
)
pwpr_lps: BinanceRestWrapper = get_rest_wrapper(
    exchange=Exchange.BINANCEUNIFIED,
    acct_type=AccountType.LPS,
    account=console_acct,
)

inst_mngr = InstrumentManager()
await inst_mngr.init_instruments(Exchange.BINANCE, InstType.LPS)
await inst_mngr.init_instruments(Exchange.BINANCE, InstType.SP)
inst_d = inst_mngr.get_insts_by_exchange(Exchange.BINANCE, InstType.LPS)
print("Total LPS insts:", len(inst_d))
# Out:
# Total LPS insts: 489

# %% [markdown]
# # Account Overview

# %%
acct_sp_rsp = await scli.get_spot_account()
uid = acct_sp_rsp.get("uid", "null")
print("===={} (uid={}) PM get account raw resp====".format(console_acct, uid))
acct_rsp = await pcli.get_account()
pprint(acct_rsp)
print()

# 手续费
print("===={} account vip level @ {}====".format(console_acct, datetime.now().isoformat()))
vip_level_resp = await scli.raw_request("GET", "/sapi/v1/account/info", auth=True)
spot_fee_resp = await scli.sapi_get_commission_rate("SOLUSDT")
lps_fee_resp = await pcli.raw_request("GET", "/papi/v1/um/commissionRate", params={"symbol": "SOLUSDT"}, auth=True)
print(vip_level_resp)
print("Spot:", spot_fee_resp)
print("Swap:", lps_fee_resp)
print()

p_pos = await pcli.get_um_position_risk()
pos_df = pd.DataFrame(p_pos)
actual_eqty = float(acct_rsp["actualEquity"])
total_pos_value = pos_df.notional.astype(float).abs().sum() if "notional" in pos_df.columns else 0
util_rate = total_pos_value / actual_eqty if actual_eqty != 0 else 0
print("===={} PM account overview====".format(console_acct))
print("actual_eqty", actual_eqty)
print("uniMMR", acct_rsp["uniMMR"])
print("total_pos_value", total_pos_value)
print("util_rate: {:.2f}%".format(util_rate * 100))
# Out:
# ====bntest01 (uid=1087907781) PM get account raw resp====
# {'accountEquity': '0.0',
#  'accountInitialMargin': '0.0',
#  'accountMaintMargin': '0.0',
#  'accountStatus': 'NORMAL',
#  'actualEquity': '0.0',
#  'totalAvailableBalance': '0.0',
#  'totalMarginOpenLoss': '0.0',
#  'uniMMR': '99999999',
#  'updateTime': 1757645123700,
#  'virtualMaxWithdrawAmount': '0.0'}
#
# ====bntest01 account vip level @ 2025-09-12T02:45:23.713631====
# {'vipLevel': 0, 'isMarginEnabled': True, 'isFutureEnabled': True, 'isOptionsEnabled': True, 'isPortfolioMarginRetailEnabled': True}
# Spot: [{'symbol': 'SOLUSDT', 'makerCommission': '0.001', 'takerCommission': '0.001'}]
# Swap: {'symbol': 'SOLUSDT', 'makerCommissionRate': '0.000200', 'takerCommissionRate': '0.000500'}
#
# ====bntest01 PM account overview====
# actual_eqty 0.0
# uniMMR 99999999
# total_pos_value 0
# util_rate: 0.00%

# %%
# Set UM position side
resp = await pcli.raw_request("GET", "/papi/v1/um/positionSide/dual", auth=True)
print("UM position side", resp)

if resp["dualSidePosition"] == True:
    resp = await pcli.raw_request("POST", "/papi/v1/um/positionSide/dual", params={"dualSidePosition":"false"}, auth=True)
    print("Set UM dual position side to false, resp:", resp)
# Out:
# UM position side {'dualSidePosition': False}

# %%
# 查询自动偿还负余额模式
pm_auto_repay_neg_status = await pcli.raw_request("GET", "/papi/v1/repay-futures-switch", auth=True)
print("PM Auto Repay Neg Balance Switch:", pm_auto_repay_neg_status)

if pm_auto_repay_neg_status["autoRepay"] != True:
    # 开启自动偿还负余额模式
    pm_auto_repay_post_resp = await pcli.raw_request("POST", "/papi/v1/repay-futures-switch", params={"autoRepay": True}, auth=True)
    print("Turn on PM Auto Repay Neg Balance:", pm_auto_repay_post_resp)
# Out:
# PM Auto Repay Neg Balance Switch: {'autoRepay': True}

# %%
# repay cm/um negative balance
await pcli.raw_request("POST", "/papi/v1/repay-futures-negative-balance", params={}, auth=True)
# 统一账户资金归集
await pcli.raw_request("POST", "/papi/v1/auto-collection", auth=True)
# Out:
# {'msg': 'success'}

# %%
# view pm balance
p_bal_resp = await pcli.get_balance()
if p_bal_resp:
    p_bal_df = pd.DataFrame(p_bal_resp).set_index("asset")
    p_bal_df["updateTime"] = p_bal_df["updateTime"].apply(lambda x: arrow.get(x).format())
    p_bal_df["crossMarginFree"] = p_bal_df["crossMarginFree"].astype(float)
    p_bal_df["crossMarginAsset"] = p_bal_df["crossMarginAsset"].astype(float)
    p_bal_df["totalWalletBalance"] = p_bal_df["totalWalletBalance"].astype(float)
    p_bal_df = p_bal_df[p_bal_df.totalWalletBalance != 0]
else:
    p_bal_df = None
p_bal_df
# Out:
# Empty DataFrame
# Columns: [totalWalletBalance, crossMarginAsset, crossMarginBorrowed, crossMarginFree, crossMarginInterest, crossMarginLocked, umWalletBalance, umUnrealizedPNL, cmWalletBalance, cmUnrealizedPNL, updateTime, negativeBalance]
# Index: []

# %%
# USDT amt in PM account
ccy = "USDT"
if p_bal_df is not None and ccy in p_bal_df.index:
    print(json.dumps(p_bal_df.loc[ccy].to_dict(), indent=2))

# %%
# View PM UM Positions
p_pos = await pcli.get_um_position_risk()
if not p_pos:
    p_pos_df = None
    print("No positions!")
else:
    p_pos_df = pd.DataFrame(p_pos).set_index("symbol")
    p_pos_df["markPrice"] = p_pos_df["markPrice"].astype(float)
    p_pos_df["notional"] = p_pos_df["notional"].astype(float)
    p_pos_df["unRealizedProfit"] = p_pos_df["unRealizedProfit"].astype(float)
    p_pos_df["unpnl_rate"] = p_pos_df["unRealizedProfit"] / actual_eqty  # unpnl占total equity的比例
    p_pos_df["util_pct"] = p_pos_df["notional"].abs() / actual_eqty
    p_pos_df["updateTime"] = p_pos_df["updateTime"].apply(lambda x: arrow.get(x).format())
    p_pos_df = p_pos_df[
        [
            "positionAmt",
            "markPrice",
            "notional",
            "util_pct",
            # "maxNotionalValue",
            "unRealizedProfit",
            "unpnl_rate",
            "leverage",
            "positionSide",
            "updateTime",
        ]
    ].sort_values("notional")
p_pos_df
# Out:
# No positions!

# %%
symbol = "BTCUSDT"
if p_pos_df is not None and symbol in p_pos_df.index:
    print(json.dumps(p_pos_df.loc[symbol].to_dict(), indent=2))

# %%
# get spot account balances
resp = await scli.get_spot_account()
s_bal_df = pd.DataFrame(resp["balances"]).set_index("asset")
s_bal_df[s_bal_df["free"].astype(float) > 0]
# Out:
#                free      locked
# asset
# BNB      0.00026739  0.00000000
# USDT   122.21869857  0.00000000
# USD1   100.00000000  0.00000000

# %%
# CM Position
p_cm_pos = await pcli.get_cm_position_risk()
p_cm_pos_df = pd.DataFrame(p_cm_pos)
p_cm_pos_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Clear odds

# %%
max_odds_to_clear = 100

# %%
# Clear positions
pos_resp = await pcli.get_position_risk("linear")
df = pd.DataFrame(pos_resp)
df["positionAmt"] = df["positionAmt"].astype(float)
df["position_notl"] = df["positionAmt"] * df["markPrice"].astype(float)
df = df[df["position_notl"].abs().apply(lambda x: 0 < x < max_odds_to_clear)][
    ["symbol", "position_notl", "positionAmt"]
].sort_values("position_notl")
df["order_side"] = df["positionAmt"].apply(lambda amt: "SELL" if Decimal(amt) > 0 else "BUY")
df["order_type"] = "MARKET"
df["reduce_only"] = True
df["order_qty"] = df["positionAmt"].apply(lambda amt: str(abs(Decimal(str(amt)))))
df = df.reset_index(drop=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 4
#       2 pos_resp = await pcli.get_position_risk("linear")
#       3 df = pd.DataFrame(pos_resp)
# ----> 4 df["positionAmt"] = df["positionAmt"].astype(float)
#       5 df["position_notl"] = df["positionAmt"] * df["markPrice"].astype(float)
#       6 df = df[df["position_notl"].abs().apply(lambda x: 0 < x < max_odds_to_clear)][
#       7     ["symbol", "position_notl", "positionAmt"]
#       8 ].sort_values("position_notl")
#
# File ~/.miniconda/envs/exli.dev/lib/python3.12/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/.miniconda/envs/exli.dev/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'positionAmt'

# %%
use_with_caution = True

for _idx, _row in df.iterrows():
    lps_orders_arg = {
        "symbol": _row["symbol"],
        "side": _row["order_side"],
        "type": _row["order_type"],
        "reduceOnly": _row["reduce_only"],
        "quantity": _row["order_qty"],
    }
    print(f"[{_idx+1}/{len(df)}] Order: {lps_orders_arg}")
    if use_with_caution:
        rsp = await pcli.place_um_order(**lps_orders_arg)
        if "code" not in rsp:
            print(f"[OK] {rsp}")
        else:
            print(f"[ERROR] {rsp}")
        await asyncio.sleep(0.5)
# Out:
# [1/1] Order: {'symbol': 'DOGEUSDT', 'side': 'SELL', 'type': 'MARKET', 'reduceOnly': True, 'quantity': '13.0'}
# [OK] {'symbol': 'DOGEUSDT', 'side': 'SELL', 'executedQty': '0', 'orderId': 81469246535, 'goodTillDate': 0, 'avgPrice': '0.000000', 'origQty': '13', 'clientOrderId': 'avXuQmQ8AOal7dXabhz270', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1757602959722, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.000000', 'cumQuote': '0.000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}

# %%
# Clear balances
def get_sp_order_size(size, min_order_size, lot_size, price, min_order_notional):
    size = float(Cast(size).quantize(lot_size, round_down=True))
    return size if (size > min_order_size and min_order_notional < size * price < max_odds_to_clear) else 0


bal_resp = await pcli.get_balance()
spot_balance_df = pd.DataFrame(bal_resp)
spot_balance_df["crossMarginFree"] = spot_balance_df["crossMarginFree"].astype(float)
spot_balance_df = spot_balance_df[spot_balance_df["crossMarginFree"] > 0][["asset", "crossMarginFree"]]
sp_inst_df = pd.DataFrame(
    [
        {
            "asset": inst.base_ccy,
            "symbol": inst.exchange_symbol,
            "lot_size": float(inst.lot_size),
            "min_order_size": float(inst.min_order_size),
            "min_order_notional": float(inst.min_order_notional),
        }
        for inst in inst_mngr.get_insts_by_exchange(Exchange.BINANCE, InstType.SP).values() if inst.quote_ccy=="USDT"
    ]
)
spot_df = pd.merge(spot_balance_df, sp_inst_df, how="left", on="asset")
px_resp = await scli.get_price()
px_ticker_df = pd.DataFrame(px_resp)
px_ticker_df["price"] = px_ticker_df["price"].astype(float)
spot_val_df = pd.merge(spot_df, px_ticker_df, how="left", on="symbol").dropna(subset=["price"])
spot_val_df["sp_notional"] = spot_val_df["crossMarginFree"] * spot_val_df["price"]
spot_val_df["order_quantity"] = spot_val_df.apply(
    lambda row: get_sp_order_size(
        row["crossMarginFree"],
        row["min_order_size"],
        row["lot_size"],
        row["price"],
        row["min_order_notional"],
    ),
    axis=1,
)
spot_val_df["order_notional"] = spot_val_df["order_quantity"] * spot_val_df["price"]
spot_val_df["order_side"] = "SELL"
spot_val_df["order_type"] = "MARKET"
spot_val_df = spot_val_df[(spot_val_df["order_quantity"] > 0) & (spot_val_df["asset"] != "BNB")]
spot_val_df = spot_val_df.reset_index(drop=True)
spot_val_df
# Out:
# Empty DataFrame
# Columns: [asset, crossMarginFree, symbol, lot_size, min_order_size, min_order_notional, price, sp_notional, order_quantity, order_notional, order_side, order_type]
# Index: []

# %%
use_with_caution = True

for _idx, _row in spot_val_df.iterrows():
    sp_orders_arg = {
        "symbol": _row["symbol"],
        "side": _row["order_side"],
        "type": _row["order_type"],
        "quantity": _row["order_quantity"],
    }
    print(f"[{_idx+1}/{len(spot_val_df)}] Order: {sp_orders_arg}")
    if use_with_caution:
        order_resp = await pcli.place_margin_order(**sp_orders_arg)
        if "code" in order_resp:
            print("[ERROR] Order={}. Resp={}".format(sp_orders_arg, order_resp))
        else:
            print("[OK] Clear {}. OrderId={}".format(sp_orders_arg["symbol"], order_resp["clientOrderId"]))
        await asyncio.sleep(0.5)

# %% [markdown]
# # Check delta & reduce delta

# %%
def to_sp_price_multiplier(exchange_symbol):
    inst = inst_mngr.get_inst_by_exchange_symbol(Exchange.BINANCE, InstType.SP, exchange_symbol=exchange_symbol)
    return None if not inst else inst.price_multiplier


def to_lps_price_multiplier(exchange_symbol):
    inst = inst_mngr.get_inst_by_exchange_symbol(Exchange.BINANCE, InstType.LPS, exchange_symbol=exchange_symbol)
    return None if not inst else inst.price_multiplier


sp_ticker_resp = await scli.get_price()
sp_ticker_df = pd.DataFrame(sp_ticker_resp)
sp_ticker_df["price"] = sp_ticker_df["price"].astype(float)
sp_ticker_df = sp_ticker_df.rename(columns={"symbol": "sp_ticker_symbol", "price": "sp_px"}, errors="raise")
sp_ticker_df["meta_symbol"] = sp_ticker_df["sp_ticker_symbol"].apply(
    lambda x: inst_mngr.get_meta_symbol_by_exchange_symbol(Exchange.BINANCE, InstType.SP, exchange_symbol=x),
)
sp_ticker_df["sp_price_multiplier"] = sp_ticker_df["sp_ticker_symbol"].apply(to_sp_price_multiplier)
sp_ticker_df = sp_ticker_df.dropna()

p_bal_resp = await pcli.get_balance()
p_bal_df = pd.DataFrame(p_bal_resp)
p_bal_df["total_sp_qty"] = p_bal_df["totalWalletBalance"].astype(float)
p_bal_df["crossMarginFree"] = p_bal_df["crossMarginFree"].astype(float)
p_bal_df["sp_ticker_symbol"] = p_bal_df["asset"].apply(lambda x: x + "USDT")
p_bal_df = p_bal_df[["asset", "total_sp_qty", "crossMarginFree", "sp_ticker_symbol"]]
p_bal_meta_df = pd.merge(left=p_bal_df, right=sp_ticker_df, how="left", on=["sp_ticker_symbol"])
p_bal_meta_df["sp_meta_qty"] = p_bal_meta_df["sp_price_multiplier"] * p_bal_meta_df["total_sp_qty"]

lps_pos = await pcli.get_um_position_risk()
lps_pos_df = pd.DataFrame(lps_pos)
lps_pos_df["pos_amt"] = lps_pos_df["positionAmt"].astype(float)
lps_pos_df["pos_notl"] = lps_pos_df["notional"].astype(float)
lps_pos_df["meta_symbol"] = lps_pos_df["symbol"].apply(
    lambda x: inst_mngr.get_meta_symbol_by_exchange_symbol(Exchange.BINANCE, InstType.LPS, exchange_symbol=x)
)
lps_pos_df = lps_pos_df[["symbol", "meta_symbol", "pos_amt", "pos_notl"]]

delta_df = pd.merge(p_bal_meta_df, lps_pos_df, on="meta_symbol", how="outer")
delta_df["lps_ticker_symbol"] = delta_df["meta_symbol"].apply(
    lambda x: inst_mngr.get_exchange_symbol_by_meta_symbol(Exchange.BINANCE, InstType.LPS, meta_symbol=x)
)
delta_df["lps_price_multiplier"] = delta_df["lps_ticker_symbol"].apply(to_lps_price_multiplier)
delta_df["pos_amt"] = delta_df["pos_amt"].fillna(0)
delta_df["lps_meta_qty"] = delta_df["lps_price_multiplier"] * delta_df["pos_amt"]
delta_df["total_sp_qty"] = delta_df["total_sp_qty"].fillna(0)
delta_df["sp_meta_qty"] = delta_df["sp_meta_qty"].fillna(0)
delta_df["delta_meta_qty"] = delta_df["sp_meta_qty"] + delta_df["lps_meta_qty"]
delta_df["delta_notl"] = delta_df["delta_meta_qty"] / delta_df["sp_price_multiplier"] * delta_df["sp_px"]
delta_df = delta_df[
    (delta_df["delta_meta_qty"] != 0)
    & (delta_df["delta_meta_qty"].notna())
    & (delta_df["delta_notl"].abs() > 10)
    & (
        delta_df["meta_symbol"].apply(
            lambda x: x
            not in [
                "BNB_USDT",
                # "BTC_USDT",
            ]
        )
    )
][
    [
        "meta_symbol",
        "asset",
        "sp_ticker_symbol",
        "total_sp_qty",
        "crossMarginFree",
        "sp_px",
        "sp_price_multiplier",
        "sp_meta_qty",
        "lps_ticker_symbol",
        "pos_amt",
        "pos_notl",
        "lps_price_multiplier",
        "lps_meta_qty",
        "delta_meta_qty",
        "delta_notl",
    ]
].set_index(
    "meta_symbol"
)

delta_df

# %%
_use_with_caution = True

for h_meta_symbol in delta_df.index.to_list():
    h_sp_inst = inst_mngr.get_inst_by_meta_symbol(Exchange.BINANCE, InstType.SP, meta_symbol=h_meta_symbol)
    h_lps_inst = inst_mngr.get_inst_by_meta_symbol(Exchange.BINANCE, InstType.LPS, meta_symbol=h_meta_symbol)
    print(f"************ meta_symbol={h_meta_symbol} ************")

    sp_qty = delta_df.loc[h_meta_symbol]["total_sp_qty"]
    lps_qty = delta_df.loc[h_meta_symbol]["pos_amt"]
    delta_meta_qty = delta_df.loc[h_meta_symbol]["delta_meta_qty"]
    delta_value = delta_df.loc[h_meta_symbol]["delta_notl"]
    print(f"sp_qty={sp_qty} lps_qty={lps_qty} delta_meta_qty={delta_meta_qty} delta_value={delta_value:.2f}")

    delta_qty_lps = Cast(float(delta_meta_qty / h_lps_inst.price_multiplier)).quantize(
        h_lps_inst.lot_size, round_down=True
    )
    order_qty_lps = quantize(abs(delta_qty_lps), h_lps_inst.lot_size, True)
    delta_qty_sp = Cast(float(delta_meta_qty / h_sp_inst.price_multiplier)).quantize(
        h_sp_inst.lot_size, round_down=True
    )
    order_qty_sp = quantize(abs(delta_qty_sp), h_sp_inst.lot_size, True)
    print(f"delta_qty_lps={delta_qty_lps} delta_qty_sp={delta_qty_sp}")

    if _use_with_caution:
        if delta_meta_qty < 0 and order_qty_lps > 0:
            rsp = await pcli.place_um_order(
                symbol=h_lps_inst.exchange_symbol,
                side="BUY",
                type="MARKET",
                quantity=str(order_qty_lps),
                reduceOnly=True,
            )
            print(rsp)
        elif delta_meta_qty > 0 and order_qty_sp > 0:
            rsp = await pcli.place_margin_order(
                symbol=h_sp_inst.exchange_symbol,
                side="SELL",
                type="MARKET",
                quantity=str(order_qty_sp),
            )
            print(rsp)

    print()
    await asyncio.sleep(0.5)
# Out:
# ************ meta_symbol=BTC_USDT ************
# sp_qty=0.01035328 lps_qty=0.0 delta_meta_qty=0.01035328 delta_value=1134.47
# delta_qty_lps=0.010 delta_qty_sp=0.01035000
# {'clientOrderId': 'NQkBUizy0snCnOteKwI72', 'cummulativeQuoteQty': '1134.10901250', 'executedQty': '0.01035000', 'fills': [{'commission': '0.00066162', 'commissionAsset': 'BNB', 'price': '109575.75000000', 'qty': '0.01035000'}], 'orderId': 44511738016, 'origQty': '0.01035000', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': 'BTCUSDT', 'timeInForce': 'GTC', 'transactTime': 1749607035527, 'type': 'MARKET'}

# %% [markdown]
# # BNB Dust

# %%
bal_resp = await pcli.get_balance()
spot_balance_df = pd.DataFrame(bal_resp)
spot_balance_df["crossMarginFree"] = spot_balance_df["crossMarginFree"].astype(float)
spot_balance_df = spot_balance_df[spot_balance_df["crossMarginFree"] > 0][["asset", "crossMarginFree"]]
sp_inst_df = pd.DataFrame(
    [
        {
            "asset": inst.base_ccy,
            "symbol": inst.exchange_symbol,
            "lot_size": float(inst.lot_size),
            "min_order_size": float(inst.min_order_size),
            "min_order_notional": float(inst.min_order_notional),
        }
        for inst in inst_mngr.get_insts_by_exchange(Exchange.BINANCE, InstType.SP).values()
        if inst.quote_ccy == "USDT"
    ]
)
spot_df = pd.merge(spot_balance_df, sp_inst_df, how="left", on="asset")
px_resp = await scli.get_price()
px_ticker_df = pd.DataFrame(px_resp)
px_ticker_df["price"] = px_ticker_df["price"].astype(float)
spot_val_df = pd.merge(spot_df, px_ticker_df, how="left", on="symbol").dropna(subset=["price"])
spot_val_df["notional"] = spot_val_df["crossMarginFree"] * spot_val_df["price"]
spot_val_df["will_dust"] = spot_val_df.apply(
    lambda row: (
        row["crossMarginFree"] < row["min_order_size"]
        or row["notional"] < 10
        or row["crossMarginFree"] * row["price"] < row["min_order_notional"]
    )
    and row["asset"] != "BNB",
    axis=1,
)
will_dust_df = (
    spot_val_df[spot_val_df["will_dust"]][["asset", "crossMarginFree", "symbol", "notional", "will_dust"]]
    .set_index("asset")
    .sort_values("notional", ascending=False)
)
will_dust_df
# Out:
#        crossMarginFree    symbol  notional  will_dust
# asset
# DOGE             0.586  DOGEUSDT  0.134522       True

# %%
# transfer dust assets from PM Margin -> Spot
use_with_caution = True

bal_resp = await pcli.get_balance()
trsf_bal_df = pd.DataFrame(bal_resp).set_index("asset")
for asset_key in will_dust_df.index.values:
    if float(trsf_bal_df.loc[asset_key]["crossMarginFree"]) > 0:
        print("Transfer {} {} from PM to SPOT".format(trsf_bal_df.loc[asset_key]["crossMarginFree"], asset_key))
        if use_with_caution:
            rsp = await scli.sapi_asset_transfer(
                type="PORTFOLIO_MARGIN_MAIN", asset=asset_key, amount=trsf_bal_df.loc[asset_key]["crossMarginFree"]
            )
            if "tranId" not in rsp:
                print("[ERROR]", rsp)
            await asyncio.sleep(0.5)
# Out:
# Transfer 0.586 DOGE from PM to SPOT

# %%
# dust preview
dust_preview_resp = await scli.sapi_asset_dustable()
dust_asset_l = list(map(lambda x: x["asset"], dust_preview_resp["details"]))
print(dust_asset_l)
# Out:
# ['DOGE']

# %%
dust_resp = await scli.sapi_asset_dust(asset=",".join(dust_asset_l))
try:
    dustChargeRate = float(dust_resp["totalServiceCharge"]) / float(dust_resp["totalTransfered"])
    print("totalTransfered={}".format(dust_resp["totalTransfered"]))
    print("totalServiceCharge={}".format(dust_resp["totalServiceCharge"]))
    print("dustChargeRate={:.2f}%".format(dustChargeRate * 100))
except:
    pprint(dust_resp)
# Out:
# totalTransfered=0.00015633
# totalServiceCharge=0.00000312
# dustChargeRate=2.00%

# %%
# transfer all spot account BNB balance to PM
resp = await scli.get_spot_account()
s_bal_df = pd.DataFrame(resp["balances"]).set_index("asset")
sp_bnb_free = float(s_bal_df.loc["BNB"].free)
if sp_bnb_free > 0:
    print("Transfer {} BNB from spot to PM".format(sp_bnb_free))
    rsp = await scli.sapi_asset_transfer(type="MAIN_PORTFOLIO_MARGIN", asset="BNB", amount=str(sp_bnb_free))
    print(rsp)
else:
    print("No BNB in spot account.")
# Out:
# Transfer 0.00015321 BNB from spot to PM
# {'tranId': 289204658849}

# %% [markdown]
# # Query orders

# %%
# get sp order status
od = await pcli.papi_v1_margin_myTrades(symbol="FDUSDUSDT", limit=1000)
pd.DataFrame(data=od)

# %%
# get lps order status
od = await pcli.papi_v1_um_userTrades(symbol="ACTUSDT", orderId=2514755808)
pd.DataFrame(data=od)
# print(od)
# Out:
#     symbol         id     orderId side      price      qty      realizedPnl  \
# 0  ACTUSDT  216328385  2514755808  BUY  0.1094110  1141044  133785.70147922
#
#          quoteQty commission commissionAsset           time positionSide  \
# 0  124842.7650840          0            USDT  1743503535616         BOTH
#
#    maker  buyer
# 0   True   True

# %%
start_time = arrow.get("2025-04-01 10:32:15").int_timestamp * 1000
end_time = arrow.get("2025-04-01 12:32:15").int_timestamp * 1000

symbol_list = ["ACTUSDT"]
sp_order_rsp = await pwpr_sp.get_order_history(symbol_list=symbol_list, start_time=start_time, end_time=end_time)
df = pd.DataFrame(
    [
        {
            "create_time": dc.create_time,
            "symbol": dc.symbol,
            "side": dc.side.name,
            "order_id": dc.order_id,
            "client_id": dc.client_id,
            "quantity": float(dc.quantity),
            "filled_price": float(dc.filled_price),
            "filled_quantity": float(dc.filled_quantity),
            "order_type": dc.order_type.name,
            "time_in_force": dc.time_in_force.name,
            "status": dc.status.name,
        }
        for dc in sp_order_rsp["data"]["ACTUSDT"]
    ]
)

# %%
total_filled_value = (df["filled_price"] * df["filled_quantity"]).sum()
total_filled_quantity = df["filled_quantity"].sum()
avg_filled_price = total_filled_value / total_filled_quantity
print("total_filled_quantity={} avg_filled_price={}".format(total_filled_quantity, avg_filled_price))
# Out:
# total_filled_quantity=1162322.2 avg_filled_price=0.10652066992267722

# %% [markdown]
# # Batch set leverage

# %%
# instrument
im = InstrumentManager()
await im.init_instruments(Exchange.BINANCE, InstType.LPS)
inst_l = im.get_insts_by_exchange(Exchange.BINANCE, InstType.LPS)

for symbol, inst in inst_l.items():
    if inst.status == InstStatus.TRADING:
        rsp = await pcli.raw_request(
            "POST",
            "/papi/v1/um/leverage",
            {"symbol": inst.exchange_symbol, "leverage": 4},
            auth=True,
        )
        if "code" in rsp:
            print("[ERROR]", symbol, rsp)
        else:
            print("[OK]", symbol, rsp)
        await asyncio.sleep(0.1)
# Out:
# [OK] BTCUSDT {'leverage': 4, 'maxNotionalValue': '600000000', 'symbol': 'BTCUSDT'}
# [OK] ETHUSDT {'leverage': 4, 'maxNotionalValue': '400000000', 'symbol': 'ETHUSDT'}
# [OK] BCHUSDT {'leverage': 4, 'maxNotionalValue': '20000000', 'symbol': 'BCHUSDT'}
# [OK] XRPUSDT {'leverage': 4, 'maxNotionalValue': '25000000', 'symbol': 'XRPUSDT'}
# [OK] LTCUSDT {'leverage': 4, 'maxNotionalValue': '20000000', 'symbol': 'LTCUSDT'}
# [OK] TRXUSDT {'leverage': 4, 'maxNotionalValue': '12000000', 'symbol': 'TRXUSDT'}
# [OK] ETCUSDT {'leverage': 4, 'maxNotionalValue': '7000000', 'symbol': 'ETCUSDT'}
# [OK] LINKUSDT {'leverage': 4, 'maxNotionalValue': '20000000', 'symbol': 'LINKUSDT'}
# [OK] XLMUSDT {'leverage': 4, 'maxNotionalValue': '12500000', 'symbol': 'XLMUSDT'}
# [OK] ADAUSDT {'leverage': 4, 'maxNotionalValue': '25000000', 'symbol': 'ADAUSDT'}
# [OK] XMRUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'XMRUSDT'}
# [OK] DASHUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'DASHUSDT'}
# [OK] ZECUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ZECUSDT'}
# [OK] XTZUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'XTZUSDT'}
# [OK] BNBUSDT {'leverage': 4, 'maxNotionalValue': '37500000', 'symbol': 'BNBUSDT'}
# [OK] ATOMUSDT {'leverage': 4, 'maxNotionalValue': '5000000', 'symbol': 'ATOMUSDT'}
# [OK] ONTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ONTUSDT'}
# [OK] IOTAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'IOTAUSDT'}
# [OK] BATUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BATUSDT'}
# [OK] VETUSDT {'leverage': 4, 'maxNotionalValue': '2000000', 'symbol': 'VETUSDT'}
# [OK] NEOUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'NEOUSDT'}
# [OK] QTUMUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'QTUMUSDT'}
# [OK] IOSTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'IOSTUSDT'}
# [OK] THETAUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'THETAUSDT'}
# [OK] ALGOUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'ALGOUSDT'}
# [OK] ZILUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ZILUSDT'}
# [OK] KNCUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'KNCUSDT'}
# [OK] ZRXUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ZRXUSDT'}
# [OK] COMPUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'COMPUSDT'}
# [OK] DOGEUSDT {'leverage': 4, 'maxNotionalValue': '50000000', 'symbol': 'DOGEUSDT'}
# [OK] SXPUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SXPUSDT'}
# [OK] KAVAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'KAVAUSDT'}
# [OK] BANDUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BANDUSDT'}
# [OK] RLCUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'RLCUSDT'}
# [OK] MKRUSDT {'leverage': 4, 'maxNotionalValue': '10000000', 'symbol': 'MKRUSDT'}
# [OK] SNXUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SNXUSDT'}
# [OK] DOTUSDT {'leverage': 4, 'maxNotionalValue': '10000000', 'symbol': 'DOTUSDT'}
# [OK] YFIUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'YFIUSDT'}
# [OK] CRVUSDT {'leverage': 4, 'maxNotionalValue': '7500000', 'symbol': 'CRVUSDT'}
# [OK] TRBUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'TRBUSDT'}
# [OK] RUNEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'RUNEUSDT'}
# [OK] SUSHIUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'SUSHIUSDT'}
# [OK] EGLDUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'EGLDUSDT'}
# [OK] SOLUSDT {'leverage': 4, 'maxNotionalValue': '100000000', 'symbol': 'SOLUSDT'}
# [OK] ICXUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ICXUSDT'}
# [OK] STORJUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'STORJUSDT'}
# [OK] UNIUSDT {'leverage': 4, 'maxNotionalValue': '12500000', 'symbol': 'UNIUSDT'}
# [OK] AVAXUSDT {'leverage': 4, 'maxNotionalValue': '20000000', 'symbol': 'AVAXUSDT'}
# [OK] ENJUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ENJUSDT'}
# [OK] FLMUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'FLMUSDT'}
# [OK] KSMUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'KSMUSDT'}
# [OK] NEARUSDT {'leverage': 4, 'maxNotionalValue': '25000000', 'symbol': 'NEARUSDT'}
# [OK] AAVEUSDT {'leverage': 4, 'maxNotionalValue': '7500000', 'symbol': 'AAVEUSDT'}
# [OK] FILUSDT {'leverage': 4, 'maxNotionalValue': '12500000', 'symbol': 'FILUSDT'}
# [OK] RSRUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'RSRUSDT'}
# [OK] LRCUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'LRCUSDT'}
# [OK] BELUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BELUSDT'}
# [OK] AXSUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'AXSUSDT'}
# [OK] ALPHAUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'ALPHAUSDT'}
# [OK] ZENUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ZENUSDT'}
# [OK] SKLUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SKLUSDT'}
# [OK] GRTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'GRTUSDT'}
# [OK] 1INCHUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': '1INCHUSDT'}
# [OK] CHZUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'CHZUSDT'}
# [OK] SANDUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SANDUSDT'}
# [OK] ANKRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ANKRUSDT'}
# [OK] RVNUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'RVNUSDT'}
# [OK] SFPUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SFPUSDT'}
# [OK] BTCSTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BTCSTUSDT'}
# [OK] COTIUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'COTIUSDT'}
# [OK] CHRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CHRUSDT'}
# [OK] MANAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'MANAUSDT'}
# [OK] ALICEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ALICEUSDT'}
# [OK] HBARUSDT {'leverage': 4, 'maxNotionalValue': '10000000', 'symbol': 'HBARUSDT'}
# [OK] ONEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ONEUSDT'}
# [OK] DENTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DENTUSDT'}
# [OK] CELRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CELRUSDT'}
# [OK] HOTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'HOTUSDT'}
# [OK] MTLUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MTLUSDT'}
# [OK] OGNUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'OGNUSDT'}
# [OK] NKNUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'NKNUSDT'}
# [OK] 1000SHIBUSDT {'leverage': 4, 'maxNotionalValue': '6000000', 'symbol': '1000SHIBUSDT'}
# [OK] BAKEUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'BAKEUSDT'}
# [OK] GTCUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'GTCUSDT'}
# [OK] BTCDOMUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BTCDOMUSDT'}
# [OK] IOTXUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'IOTXUSDT'}
# [OK] C98USDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'C98USDT'}
# [OK] MASKUSDT {'leverage': 4, 'maxNotionalValue': '300000', 'symbol': 'MASKUSDT'}
# [OK] ATAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ATAUSDT'}
# [OK] DYDXUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'DYDXUSDT'}
# [OK] 1000XECUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': '1000XECUSDT'}
# [OK] GALAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'GALAUSDT'}
# [OK] CELOUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'CELOUSDT'}
# [OK] ARUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ARUSDT'}
# [OK] ARPAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ARPAUSDT'}
# [OK] CTSIUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CTSIUSDT'}
# [OK] LPTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'LPTUSDT'}
# [OK] ENSUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'ENSUSDT'}
# [OK] PEOPLEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PEOPLEUSDT'}
# [OK] ROSEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ROSEUSDT'}
# [OK] DUSKUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DUSKUSDT'}
# [OK] FLOWUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'FLOWUSDT'}
# [OK] IMXUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'IMXUSDT'}
# [OK] API3USDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'API3USDT'}
# [OK] GMTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'GMTUSDT'}
# [OK] APEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'APEUSDT'}
# [OK] WOOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'WOOUSDT'}
# [OK] JASMYUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'JASMYUSDT'}
# [OK] OPUSDT {'leverage': 4, 'maxNotionalValue': '7500000', 'symbol': 'OPUSDT'}
# [OK] INJUSDT {'leverage': 4, 'maxNotionalValue': '6000000', 'symbol': 'INJUSDT'}
# [OK] STGUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'STGUSDT'}
# [OK] SPELLUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SPELLUSDT'}
# [OK] 1000LUNCUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': '1000LUNCUSDT'}
# [OK] LUNA2USDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'LUNA2USDT'}
# [OK] LDOUSDT {'leverage': 4, 'maxNotionalValue': '5000000', 'symbol': 'LDOUSDT'}
# [OK] ICPUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'ICPUSDT'}
# [OK] APTUSDT {'leverage': 4, 'maxNotionalValue': '8000000', 'symbol': 'APTUSDT'}
# [OK] QNTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'QNTUSDT'}
# [OK] FETUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'FETUSDT'}
# [OK] FXSUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'FXSUSDT'}
# [OK] HOOKUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'HOOKUSDT'}
# [OK] MAGICUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'MAGICUSDT'}
# [OK] TUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TUSDT'}
# [OK] HIGHUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'HIGHUSDT'}
# [OK] MINAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'MINAUSDT'}
# [OK] ASTRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ASTRUSDT'}
# [OK] PHBUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PHBUSDT'}
# [OK] GMXUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'GMXUSDT'}
# [OK] CFXUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'CFXUSDT'}
# [OK] STXUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'STXUSDT'}
# [OK] ACHUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ACHUSDT'}
# [OK] SSVUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SSVUSDT'}
# [OK] CKBUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CKBUSDT'}
# [OK] PERPUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'PERPUSDT'}
# [OK] TRUUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TRUUSDT'}
# [OK] LQTYUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'LQTYUSDT'}
# [OK] USDCUSDT {'leverage': 4, 'maxNotionalValue': '6000000', 'symbol': 'USDCUSDT'}
# [OK] IDUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'IDUSDT'}
# [OK] ARBUSDT {'leverage': 4, 'maxNotionalValue': '6000000', 'symbol': 'ARBUSDT'}
# [OK] JOEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'JOEUSDT'}
# [OK] TLMUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TLMUSDT'}
# [OK] LEVERUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'LEVERUSDT'}
# [OK] RDNTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'RDNTUSDT'}
# [OK] HFTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'HFTUSDT'}
# [OK] XVSUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'XVSUSDT'}
# [OK] BLURUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'BLURUSDT'}
# [OK] EDUUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'EDUUSDT'}
# [OK] SUIUSDT {'leverage': 4, 'maxNotionalValue': '25000000', 'symbol': 'SUIUSDT'}
# [OK] 1000PEPEUSDT {'leverage': 4, 'maxNotionalValue': '25000000', 'symbol': '1000PEPEUSDT'}
# [OK] 1000FLOKIUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': '1000FLOKIUSDT'}
# [OK] UMAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'UMAUSDT'}
# [OK] NMRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'NMRUSDT'}
# [OK] MAVUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MAVUSDT'}
# [OK] XVGUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'XVGUSDT'}
# [OK] WLDUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'WLDUSDT'}
# [OK] PENDLEUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'PENDLEUSDT'}
# [OK] ARKMUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ARKMUSDT'}
# [OK] AGLDUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AGLDUSDT'}
# [OK] YGGUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'YGGUSDT'}
# [OK] DODOXUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DODOXUSDT'}
# [OK] BNTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BNTUSDT'}
# [OK] OXTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'OXTUSDT'}
# [OK] SEIUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'SEIUSDT'}
# [OK] CYBERUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CYBERUSDT'}
# [OK] HIFIUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'HIFIUSDT'}
# [OK] ARKUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'ARKUSDT'}
# [OK] BICOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BICOUSDT'}
# [OK] BIGTIMEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'BIGTIMEUSDT'}
# [OK] WAXPUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'WAXPUSDT'}
# [OK] BSVUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BSVUSDT'}
# [OK] RIFUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'RIFUSDT'}
# [OK] POLYXUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'POLYXUSDT'}
# [OK] GASUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'GASUSDT'}
# [OK] POWRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'POWRUSDT'}
# [OK] TIAUSDT {'leverage': 4, 'maxNotionalValue': '7000000', 'symbol': 'TIAUSDT'}
# [OK] CAKEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'CAKEUSDT'}
# [OK] MEMEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'MEMEUSDT'}
# [OK] TWTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TWTUSDT'}
# [OK] TOKENUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TOKENUSDT'}
# [OK] ORDIUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ORDIUSDT'}
# [OK] STEEMUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'STEEMUSDT'}
# [OK] ILVUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ILVUSDT'}
# [OK] NTRNUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'NTRNUSDT'}
# [OK] KASUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'KASUSDT'}
# [OK] BEAMXUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'BEAMXUSDT'}
# [OK] 1000BONKUSDT {'leverage': 4, 'maxNotionalValue': '10000000', 'symbol': '1000BONKUSDT'}
# [OK] PYTHUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'PYTHUSDT'}
# [OK] SUPERUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SUPERUSDT'}
# [OK] USTCUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'USTCUSDT'}
# [OK] ONGUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ONGUSDT'}
# [OK] ETHWUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ETHWUSDT'}
# [OK] JTOUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'JTOUSDT'}
# [OK] 1000SATSUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': '1000SATSUSDT'}
# [OK] AUCTIONUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'AUCTIONUSDT'}
# [OK] 1000RATSUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': '1000RATSUSDT'}
# [OK] ACEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ACEUSDT'}
# [OK] MOVRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MOVRUSDT'}
# [OK] NFPUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'NFPUSDT'}
# [OK] AIUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AIUSDT'}
# [OK] XAIUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'XAIUSDT'}
# [OK] WIFUSDT {'leverage': 4, 'maxNotionalValue': '10000000', 'symbol': 'WIFUSDT'}
# [OK] MANTAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MANTAUSDT'}
# [OK] ONDOUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'ONDOUSDT'}
# [OK] LSKUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'LSKUSDT'}
# [OK] ALTUSDT {'leverage': 4, 'maxNotionalValue': '300000', 'symbol': 'ALTUSDT'}
# [OK] JUPUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'JUPUSDT'}
# [OK] ZETAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ZETAUSDT'}
# [OK] RONINUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'RONINUSDT'}
# [OK] DYMUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DYMUSDT'}
# [OK] OMUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'OMUSDT'}
# [OK] PIXELUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PIXELUSDT'}
# [OK] STRKUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'STRKUSDT'}
# [OK] GLMUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'GLMUSDT'}
# [OK] PORTALUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'PORTALUSDT'}
# [OK] TONUSDT {'leverage': 4, 'maxNotionalValue': '6000000', 'symbol': 'TONUSDT'}
# [OK] AXLUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'AXLUSDT'}
# [OK] MYROUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MYROUSDT'}
# [OK] METISUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'METISUSDT'}
# [OK] AEVOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AEVOUSDT'}
# [OK] VANRYUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'VANRYUSDT'}
# [OK] BOMEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'BOMEUSDT'}
# [OK] ETHFIUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ETHFIUSDT'}
# [OK] ENAUSDT {'leverage': 4, 'maxNotionalValue': '20000000', 'symbol': 'ENAUSDT'}
# [OK] WUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'WUSDT'}
# [OK] TNSRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TNSRUSDT'}
# [OK] SAGAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SAGAUSDT'}
# [OK] TAOUSDT {'leverage': 4, 'maxNotionalValue': '12500000', 'symbol': 'TAOUSDT'}
# [OK] OMNIUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'OMNIUSDT'}
# [OK] REZUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'REZUSDT'}
# [OK] BBUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BBUSDT'}
# [OK] NOTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'NOTUSDT'}
# [OK] TURBOUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'TURBOUSDT'}
# [OK] IOUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'IOUSDT'}
# [OK] ZKUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ZKUSDT'}
# [OK] MEWUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MEWUSDT'}
# [OK] LISTAUSDT {'leverage': 4, 'maxNotionalValue': '333333', 'symbol': 'LISTAUSDT'}
# [OK] ZROUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ZROUSDT'}
# [OK] RENDERUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'RENDERUSDT'}
# [OK] BANANAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BANANAUSDT'}
# [OK] RAREUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'RAREUSDT'}
# [OK] GUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'GUSDT'}
# [OK] SYNUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SYNUSDT'}
# [OK] SYSUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SYSUSDT'}
# [OK] VOXELUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'VOXELUSDT'}
# [OK] BRETTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'BRETTUSDT'}
# [OK] POPCATUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'POPCATUSDT'}
# [OK] SUNUSDT {'leverage': 4, 'maxNotionalValue': '300000', 'symbol': 'SUNUSDT'}
# [OK] DOGSUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'DOGSUSDT'}
# [OK] MBOXUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MBOXUSDT'}
# [OK] CHESSUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CHESSUSDT'}
# [OK] FLUXUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'FLUXUSDT'}
# [OK] BSWUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'BSWUSDT'}
# [OK] QUICKUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'QUICKUSDT'}
# [OK] NEIROETHUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'NEIROETHUSDT'}
# [OK] RPLUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'RPLUSDT'}
# [OK] POLUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'POLUSDT'}
# [OK] UXLINKUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'UXLINKUSDT'}
# [OK] 1MBABYDOGEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': '1MBABYDOGEUSDT'}
# [OK] NEIROUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'NEIROUSDT'}
# [OK] KDAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'KDAUSDT'}
# [OK] FIDAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'FIDAUSDT'}
# [OK] FIOUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'FIOUSDT'}
# [OK] CATIUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CATIUSDT'}
# [OK] GHSTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'GHSTUSDT'}
# [OK] HMSTRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'HMSTRUSDT'}
# [OK] REIUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'REIUSDT'}
# [OK] COSUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'COSUSDT'}
# [OK] EIGENUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'EIGENUSDT'}
# [OK] DIAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DIAUSDT'}
# [OK] 1000CATUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': '1000CATUSDT'}
# [OK] SCRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SCRUSDT'}
# [OK] GOATUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'GOATUSDT'}
# [OK] MOODENGUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'MOODENGUSDT'}
# [OK] SAFEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SAFEUSDT'}
# [OK] SANTOSUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SANTOSUSDT'}
# [OK] PONKEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PONKEUSDT'}
# [OK] COWUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'COWUSDT'}
# [OK] CETUSUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CETUSUSDT'}
# [OK] 1000000MOGUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': '1000000MOGUSDT'}
# [OK] GRASSUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'GRASSUSDT'}
# [OK] DRIFTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DRIFTUSDT'}
# [OK] SWELLUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'SWELLUSDT'}
# [OK] ACTUSDT {'leverage': 4, 'maxNotionalValue': '430000', 'symbol': 'ACTUSDT'}
# [OK] PNUTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'PNUTUSDT'}
# [OK] HIPPOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'HIPPOUSDT'}
# [OK] 1000XUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': '1000XUSDT'}
# [OK] DEGENUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DEGENUSDT'}
# [OK] BANUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BANUSDT'}
# [OK] AKTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AKTUSDT'}
# [OK] SLERFUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SLERFUSDT'}
# [OK] SCRTUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'SCRTUSDT'}
# [OK] 1000CHEEMSUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': '1000CHEEMSUSDT'}
# [OK] 1000WHYUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': '1000WHYUSDT'}
# [OK] THEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'THEUSDT'}
# [OK] MORPHOUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'MORPHOUSDT'}
# [OK] CHILLGUYUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'CHILLGUYUSDT'}
# [OK] KAIAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'KAIAUSDT'}
# [OK] AEROUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'AEROUSDT'}
# [OK] ACXUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ACXUSDT'}
# [OK] ORCAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ORCAUSDT'}
# [OK] MOVEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'MOVEUSDT'}
# [OK] RAYSOLUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'RAYSOLUSDT'}
# [OK] KOMAUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'KOMAUSDT'}
# [OK] VIRTUALUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'VIRTUALUSDT'}
# [OK] SPXUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SPXUSDT'}
# [OK] MEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MEUSDT'}
# [OK] AVAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AVAUSDT'}
# [OK] DEGOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DEGOUSDT'}
# [OK] VELODROMEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'VELODROMEUSDT'}
# [OK] MOCAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'MOCAUSDT'}
# [OK] VANAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'VANAUSDT'}
# [OK] PENGUUSDT {'leverage': 4, 'maxNotionalValue': '4500000', 'symbol': 'PENGUUSDT'}
# [OK] LUMIAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'LUMIAUSDT'}
# [OK] USUALUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'USUALUSDT'}
# [OK] AIXBTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'AIXBTUSDT'}
# [OK] FARTCOINUSDT {'leverage': 4, 'maxNotionalValue': '10000000', 'symbol': 'FARTCOINUSDT'}
# [OK] KMNOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'KMNOUSDT'}
# [OK] CGPTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CGPTUSDT'}
# [OK] HIVEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'HIVEUSDT'}
# [OK] DEXEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'DEXEUSDT'}
# [OK] PHAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PHAUSDT'}
# [OK] DFUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DFUSDT'}
# [OK] GRIFFAINUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'GRIFFAINUSDT'}
# [OK] AI16ZUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AI16ZUSDT'}
# [OK] ZEREBROUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ZEREBROUSDT'}
# [OK] BIOUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'BIOUSDT'}
# [OK] COOKIEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'COOKIEUSDT'}
# [OK] ALCHUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ALCHUSDT'}
# [OK] SWARMSUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SWARMSUSDT'}
# [OK] SONICUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SONICUSDT'}
# [OK] DUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DUSDT'}
# [OK] PROMUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PROMUSDT'}
# [OK] SUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'SUSDT'}
# [OK] SOLVUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SOLVUSDT'}
# [OK] ARCUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ARCUSDT'}
# [OK] AVAAIUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AVAAIUSDT'}
# [OK] TRUMPUSDT {'leverage': 4, 'maxNotionalValue': '2500000', 'symbol': 'TRUMPUSDT'}
# [OK] MELANIAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'MELANIAUSDT'}
# [OK] VTHOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'VTHOUSDT'}
# [OK] ANIMEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ANIMEUSDT'}
# [OK] VINEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'VINEUSDT'}
# [OK] PIPPINUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PIPPINUSDT'}
# [OK] VVVUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'VVVUSDT'}
# [OK] BERAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'BERAUSDT'}
# [OK] TSTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TSTUSDT'}
# [OK] LAYERUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'LAYERUSDT'}
# [OK] HEIUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'HEIUSDT'}
# [OK] B3USDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'B3USDT'}
# [OK] IPUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'IPUSDT'}
# [OK] GPSUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'GPSUSDT'}
# [OK] SHELLUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SHELLUSDT'}
# [OK] KAITOUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'KAITOUSDT'}
# [OK] REDUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'REDUSDT'}
# [OK] VICUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'VICUSDT'}
# [OK] EPICUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'EPICUSDT'}
# [OK] BMTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BMTUSDT'}
# [OK] MUBARAKUSDT {'leverage': 4, 'maxNotionalValue': '360000', 'symbol': 'MUBARAKUSDT'}
# [OK] FORMUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'FORMUSDT'}
# [OK] BIDUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BIDUSDT'}
# [OK] TUTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TUTUSDT'}
# [OK] BROCCOLI714USDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BROCCOLI714USDT'}
# [OK] BROCCOLIF3BUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'BROCCOLIF3BUSDT'}
# [OK] SIRENUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SIRENUSDT'}
# [OK] BANANAS31USDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BANANAS31USDT'}
# [OK] BRUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'BRUSDT'}
# [OK] PLUMEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'PLUMEUSDT'}
# [OK] NILUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'NILUSDT'}
# [OK] PARTIUSDT {'leverage': 4, 'maxNotionalValue': '430000', 'symbol': 'PARTIUSDT'}
# [OK] JELLYJELLYUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'JELLYJELLYUSDT'}
# [OK] MAVIAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MAVIAUSDT'}
# [OK] PAXGUSDT {'leverage': 4, 'maxNotionalValue': '4500000', 'symbol': 'PAXGUSDT'}
# [OK] WALUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'WALUSDT'}
# [OK] FUNUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'FUNUSDT'}
# [OK] MLNUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MLNUSDT'}
# [OK] GUNUSDT {'leverage': 4, 'maxNotionalValue': '325000', 'symbol': 'GUNUSDT'}
# [OK] ATHUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ATHUSDT'}
# [OK] BABYUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'BABYUSDT'}
# [OK] FORTHUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'FORTHUSDT'}
# [OK] PROMPTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'PROMPTUSDT'}
# [OK] XCNUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'XCNUSDT'}
# [OK] STOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'STOUSDT'}
# [OK] FHEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'FHEUSDT'}
# [OK] KERNELUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'KERNELUSDT'}
# [OK] WCTUSDT {'leverage': 4, 'maxNotionalValue': '375000', 'symbol': 'WCTUSDT'}
# [OK] INITUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'INITUSDT'}
# [OK] AERGOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AERGOUSDT'}
# [OK] BANKUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BANKUSDT'}
# [OK] EPTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'EPTUSDT'}
# [OK] DEEPUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'DEEPUSDT'}
# [OK] HYPERUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'HYPERUSDT'}
# [OK] FISUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'FISUSDT'}
# [OK] JSTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'JSTUSDT'}
# [OK] SIGNUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SIGNUSDT'}
# [OK] PUNDIXUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PUNDIXUSDT'}
# [OK] CTKUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CTKUSDT'}
# [OK] AIOTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AIOTUSDT'}
# [OK] DOLOUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'DOLOUSDT'}
# [OK] HAEDALUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'HAEDALUSDT'}
# [OK] SXTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SXTUSDT'}
# [OK] ASRUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ASRUSDT'}
# [OK] ALPINEUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ALPINEUSDT'}
# [OK] B2USDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'B2USDT'}
# [OK] MILKUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MILKUSDT'}
# [OK] SYRUPUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SYRUPUSDT'}
# [OK] OBOLUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'OBOLUSDT'}
# [OK] DOODUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DOODUSDT'}
# [OK] OGUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'OGUSDT'}
# [OK] ZKJUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ZKJUSDT'}
# [OK] SKYAIUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SKYAIUSDT'}
# [OK] NXPCUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'NXPCUSDT'}
# [OK] CVCUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CVCUSDT'}
# [OK] AGTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AGTUSDT'}
# [OK] AWEUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'AWEUSDT'}
# [OK] BUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'BUSDT'}
# [OK] SOONUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SOONUSDT'}
# [OK] HUMAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'HUMAUSDT'}
# [OK] AUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'AUSDT'}
# [OK] SOPHUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SOPHUSDT'}
# [OK] MERLUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MERLUSDT'}
# [OK] HYPEUSDT {'leverage': 4, 'maxNotionalValue': '4500000', 'symbol': 'HYPEUSDT'}
# [OK] BDXNUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'BDXNUSDT'}
# [OK] PUFFERUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PUFFERUSDT'}
# [OK] PORT3USDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PORT3USDT'}
# [OK] 1000000BOBUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': '1000000BOBUSDT'}
# [OK] LAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'LAUSDT'}
# [OK] SKATEUSDT {'leverage': 4, 'maxNotionalValue': '100000', 'symbol': 'SKATEUSDT'}
# [OK] HOMEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'HOMEUSDT'}
# [OK] RESOLVUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'RESOLVUSDT'}
# [OK] TAIKOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TAIKOUSDT'}
# [OK] SQDUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SQDUSDT'}
# [OK] PUMPBTCUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PUMPBTCUSDT'}
# [OK] SPKUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'SPKUSDT'}
# [OK] MYXUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MYXUSDT'}
# [OK] FUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'FUSDT'}
# [OK] NEWTUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'NEWTUSDT'}
# [OK] DMCUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DMCUSDT'}
# [OK] HUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'HUSDT'}
# [OK] OLUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'OLUSDT'}
# [OK] SAHARAUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'SAHARAUSDT'}
# [OK] ICNTUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ICNTUSDT'}
# [OK] BULLAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'BULLAUSDT'}
# [OK] IDOLUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'IDOLUSDT'}
# [OK] MUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'MUSDT'}
# [OK] TANSSIUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TANSSIUSDT'}
# [OK] PUMPUSDT {'leverage': 4, 'maxNotionalValue': '10000000', 'symbol': 'PUMPUSDT'}
# [OK] CROSSUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CROSSUSDT'}
# [OK] AINUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AINUSDT'}
# [OK] CUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CUSDT'}
# [OK] VELVETUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'VELVETUSDT'}
# [OK] TACUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TACUSDT'}
# [OK] ERAUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'ERAUSDT'}
# [OK] TAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TAUSDT'}
# [OK] CVXUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'CVXUSDT'}
# [OK] SLPUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'SLPUSDT'}
# [OK] ZORAUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'ZORAUSDT'}
# [OK] TAGUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'TAGUSDT'}
# [OK] ZRCUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ZRCUSDT'}
# [OK] ESPORTSUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'ESPORTSUSDT'}
# [OK] TREEUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'TREEUSDT'}
# [OK] A2ZUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'A2ZUSDT'}
# [OK] PLAYUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'PLAYUSDT'}
# [OK] NAORISUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'NAORISUSDT'}
# [OK] TOWNSUSDT {'leverage': 4, 'maxNotionalValue': '500000', 'symbol': 'TOWNSUSDT'}
# [OK] PROVEUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'PROVEUSDT'}
# [OK] ALLUSDT {'leverage': 4, 'maxNotionalValue': '1500000', 'symbol': 'ALLUSDT'}
# [OK] INUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'INUSDT'}
# [OK] YALAUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'YALAUSDT'}
# [OK] CARVUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CARVUSDT'}
# [OK] AIOUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'AIOUSDT'}
# [OK] XNYUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'XNYUSDT'}
# [OK] USELESSUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'USELESSUSDT'}
# [OK] DAMUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'DAMUSDT'}
# [OK] CUDISUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'CUDISUSDT'}
# [OK] SAPIENUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'SAPIENUSDT'}
# [OK] XPLUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'XPLUSDT'}
# [OK] WLFIUSDT {'leverage': 4, 'maxNotionalValue': '250000', 'symbol': 'WLFIUSDT'}

# %% [markdown]
# ## Transfer

# %%
p_bal_resp = await pcli.get_balance()
p_bal_df = pd.DataFrame(p_bal_resp).set_index("asset")
p_bal_df.loc["USDT"]
# Out:
# totalWalletBalance      158.26241723
# crossMarginAsset        158.26241723
# crossMarginBorrowed              0.0
# crossMarginFree         158.26241723
# crossMarginInterest              0.0
# crossMarginLocked                0.0
# umWalletBalance                  0.0
# umUnrealizedPNL          -0.78290781
# cmWalletBalance                  0.0
# cmUnrealizedPNL                  0.0
# updateTime             1756039209241
# negativeBalance                  0.0
# Name: USDT, dtype: object

# %%
resp = await scli.get_spot_account()
s_bal_df = pd.DataFrame(resp["balances"]).set_index("asset")
s_bal_df.free = s_bal_df.free.astype(float)
s_bal_df[s_bal_df.free > 0]
# Out:
#              free      locked
# asset
# BNB      0.000351  0.00000000
# DOGE   199.000000  0.00000000

# %%
# transfer some asset (ALL BALANCE!) from PM Margin -> Spot
trsf_asset = "PEPE"

_use_with_caution = False
if _use_with_caution:
    rsp = await scli.sapi_asset_transfer(
        type="PORTFOLIO_MARGIN_MAIN",
        asset=trsf_asset,
        amount=p_bal_df.loc[trsf_asset].totalWalletBalance,
    )
    print(rsp)

# %%
# transfer some asset from PM Margin -> Spot
rsp = await scli.sapi_asset_transfer(type="PORTFOLIO_MARGIN_MAIN", asset="USDT", amount=16122.58)
print(rsp)
# Out:
# {'tranId': 232660733113}

# %%
# transfer some asset from Spot -> PM Margin
rsp = await scli.sapi_asset_transfer(type="MAIN_PORTFOLIO_MARGIN", asset="DOGE", amount=100)
print(rsp)
# Out:
# {'tranId': 214154627817}

# %%
# transfer all asset from Spot -> PM Margin
resp = await scli.get_spot_account()
bal_df = pd.DataFrame(resp["balances"])

for _, _row in bal_df.iterrows():
    if float(_row["free"]) > 0:
        print("Transfer {} {} from spot to PM".format(_row["asset"], _row["free"]))
        rsp = await scli.sapi_asset_transfer(type="MAIN_PORTFOLIO_MARGIN", asset=_row["asset"], amount=_row["free"])
        print(rsp)

# %%
# Transfer all BNB from UM to MARGIN
p_bal_resp = await pcli.get_balance()
p_bal_df = pd.DataFrame(p_bal_resp).set_index("asset")
if float(p_bal_df.loc["BNB"]["umWalletBalance"]) > 0:
    rsp = await pcli.raw_request(
        "POST",
        "/papi/v1/bnb-transfer",
        params={"amount": p_bal_df.loc["BNB"]["umWalletBalance"], "transferSide": "FROM_UM"},
        auth=True,
    )
    print(rsp)

# %%
# repay cm/um negative balance
repay_resp = await pcli.raw_request("POST", "/papi/v1/repay-futures-negative-balance", params={}, auth=True)
print(repay_resp)
# 统一账户资金归集
collect_resp = await pcli.raw_request("POST", "/papi/v1/auto-collection", auth=True)
print(collect_resp)
# Out:
# {'msg': 'success'}
# {'msg': 'success'}

# %%
# PM margin interest > 0 OR loan > 0
p_bal_resp = await pcli.get_balance()
p_bal_df = pd.DataFrame(p_bal_resp)
p_bal_df[(p_bal_df.crossMarginInterest.astype(float) > 0) | (p_bal_df.crossMarginBorrowed.astype(float) > 0)]
# Out:
# Empty DataFrame
# Columns: [asset, totalWalletBalance, crossMarginAsset, crossMarginBorrowed, crossMarginFree, crossMarginInterest, crossMarginLocked, umWalletBalance, umUnrealizedPNL, cmWalletBalance, cmUnrealizedPNL, updateTime, negativeBalance]
# Index: []

# %%
# PM UM Balance != 0
p_bal_df[p_bal_df.umWalletBalance.astype(float) != 0]
# Out:
# Empty DataFrame
# Columns: [asset, totalWalletBalance, crossMarginAsset, crossMarginBorrowed, crossMarginFree, crossMarginInterest, crossMarginLocked, umWalletBalance, umUnrealizedPNL, cmWalletBalance, cmUnrealizedPNL, updateTime, negativeBalance]
# Index: []

# %%
p_bal_df[p_bal_df.asset == "USDT"]
# Out:
#   asset totalWalletBalance crossMarginAsset crossMarginBorrowed  \
# 1  USDT       158.26241723     158.26241723                 0.0
#
#   crossMarginFree crossMarginInterest crossMarginLocked umWalletBalance  \
# 1    158.26241723                 0.0               0.0             0.0
#
#   umUnrealizedPNL cmWalletBalance cmUnrealizedPNL     updateTime  \
# 1        -0.78108             0.0             0.0  1756039656598
#
#   negativeBalance
# 1             0.0

# %%
# repay margin loan & interest
await pcli.raw_request(
    "POST",
    "/papi/v1/repayLoan",
    params={
        "asset": "USDT",
        "amount": 8,
    },
    auth=True,
)
# Out:
# {'tranId': 254688050863}

# %%
# pm margin loan, Use with CAUTION!!!

_use_with_caution = False
if _use_with_caution:
    rsp = await pcli.raw_request(
        "POST",
        "/papi/v1/marginLoan",
        params={
            "amount": "100000",
            "asset": "USDT",
        },
        auth=True,
    )
    print(rsp)

# %%
# transfer all assets from PM Margin -> Spot
p_bal_resp = await pcli.get_balance()

_use_with_caution = True
if _use_with_caution:
    for asset in p_bal_resp:
        if float(asset["crossMarginFree"]) > 0 :#and asset["asset"] != "USDT":
            print("Transfer {} {} from PM to SPOT".format(asset["crossMarginFree"], asset["asset"]))
            rsp = await scli.sapi_asset_transfer(type="PORTFOLIO_MARGIN_MAIN", asset=asset["asset"], amount=asset["crossMarginFree"])
            if "tranId" not in rsp:
                print("[ERROR]", rsp)
            await asyncio.sleep(0.5)
# Out:
# Transfer 0.00035089 BNB from PM to SPOT
# Transfer 222.14869857 USDT from PM to SPOT

# %% [markdown]
# # Buy/Sell PM Margin asset

# %%
# buy/sell pm margin asset, Use with CAUTION!!!

_use_with_caution = False

if _use_with_caution:
    rsp = await pcli.place_margin_order(
        symbol="USDCUSDT",
        side="BUY",
        type="MARKET",
        quantity="5",
    )
    print(rsp)
# Out:
# {'clientOrderId': '6Bq7hKH1VQiQVedi732428', 'cummulativeQuoteQty': '5.00200000', 'executedQty': '5.00000000', 'fills': [{'commission': '0.00000000', 'commissionAsset': 'BNB', 'price': '1.00040000', 'qty': '5.00000000'}], 'orderId': 859912908, 'origQty': '5.00000000', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'BUY', 'status': 'FILLED', 'symbol': 'USDCUSDT', 'timeInForce': 'GTC', 'transactTime': 1742478735093, 'type': 'MARKET'}

# %% [markdown]
# # Buy/Sell spot asset

# %%
# VWAP spot account, Use with CAUTION!!!

_use_with_caution = False
_n_orders = 1
_qty = 0.00224

if _use_with_caution:
    for i in range(_n_orders):
        rsp = await pcli.place_margin_order(
            symbol="BTCUSDT",
            side="SELL",
            type="MARKET",
            quantity=_qty,
        )
        print("[{}] order id = {}".format(i+1, rsp["orderId"]))
        await asyncio.sleep(1)
# Out:
# [1] order id = 44517664951

# %%
# buy/sell spot asset, Use with CAUTION!!!

_use_with_caution = False
if _use_with_caution:
    rsp = await scli.spot_order(
        symbol="BNBUSDT",
        side="SELL",
        type="MARKET",
        quantity="0.162",
    )
    print(rsp)
# Out:
# {'symbol': 'BNBUSDT', 'orderId': 8229018379, 'orderListId': -1, 'clientOrderId': 'QlJ18Pi5SCBnl57gyMO28r', 'transactTime': 1749630650986, 'price': '0.00000000', 'origQty': '0.16200000', 'executedQty': '0.16200000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '108.80406000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'SELL', 'workingTime': 1749630650986, 'fills': [{'price': '671.63000000', 'qty': '0.16200000', 'commission': '0.00006317', 'commissionAsset': 'BNB', 'tradeId': 1075472526}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}

# %% [markdown]
# # Dust spot account

# %%
# get spot account balances
resp = await scli.get_spot_account()
bal_df = pd.DataFrame(resp["balances"])

resp = await scli.sapi_asset_dustable()
asset_l = list(map(lambda x: x["asset"], resp["details"]))
bal_df["will_dust"] = bal_df["asset"].apply(lambda x: x in asset_l)

# %%
bal_df[bal_df.will_dust == True]
# Out:
#      asset        free      locked  will_dust
# 179   DOGE  0.12100000  0.00000000       True
# 555   ORDI  0.19840000  0.00000000       True
# 557    TIA  0.00500000  0.00000000       True
# 582    WIF  0.00374000  0.00000000       True
# 608  HMSTR      245.54        0.00       True
# 610  NEIRO        0.57        0.00       True
# 617   PNUT  0.56950000  0.00000000       True
# 618    ACT  0.50500000  0.00000000       True

# %%
resp = await scli.sapi_asset_dust(asset=','.join(asset_l))
resp
# Out:
# {'totalTransfered': '0.00534385',
#  'totalServiceCharge': '0.00010684',
#  'transferResult': [{'tranId': 240696741070,
#    'fromAsset': 'ACT',
#    'amount': '0.505',
#    'transferedAmount': '0.00016816',
#    'serviceChargeAmount': '0.00000336',
#    'operateTime': 1738833231395},
#   {'tranId': 240696741070,
#    'fromAsset': 'NEIRO',
#    'amount': '0.57',
#    'transferedAmount': '0.00000034',
#    'serviceChargeAmount': '0',
#    'operateTime': 1738833231385},
#   {'tranId': 240696741070,
#    'fromAsset': 'WIF',
#    'amount': '0.00374',
#    'transferedAmount': '0.00000525',
#    'serviceChargeAmount': '0.0000001',
#    'operateTime': 1738833231386},
#   {'tranId': 240696741070,
#    'fromAsset': 'HMSTR',
#    'amount': '245.54',
#    'transferedAmount': '0.00073093',
#    'serviceChargeAmount': '0.00001461',
#    'operateTime': 1738833231395},
#   {'tranId': 240696741070,
#    'fromAsset': 'PNUT',
#    'amount': '0.5695',
#    'transferedAmount': '0.00017757',
#    'serviceChargeAmount': '0.00000355',
#    'operateTime': 1738833231395},
#   {'tranId': 240696741070,
#    'fromAsset': 'DOGE',
#    'amount': '0.121',
#    'transferedAmount': '0.00005516',
#    'serviceChargeAmount': '0.0000011',
#    'operateTime': 1738833231396},
#   {'tranId': 240696741070,
#    'fromAsset': 'ORDI',
#    'amount': '0.1984',
#    'transferedAmount': '0.00418004',
#    'serviceChargeAmount': '0.0000836',
#    'operateTime': 1738833231396},
#   {'tranId': 240696741070,
#    'fromAsset': 'TIA',
#    'amount': '0.005',
#    'transferedAmount': '0.0000264',
#    'serviceChargeAmount': '0.00000052',
#    'operateTime': 1738833231396}]}

# %% [markdown]
# # UM Position Operations

# %%
# Place UM Order
_use_with_caution = True
if _use_with_caution:
    rsp = await pcli.place_um_order(
        symbol="BTCUSDT",
        side="BUY",
        type="MARKET",
        quantity=0.007,
    )
    print("order_id={} resp={}".format(rsp["orderId"], rsp))
# Out:
# order_id=704325701344 resp={'symbol': 'BTCUSDT', 'side': 'BUY', 'executedQty': '0.000', 'orderId': 704325701344, 'goodTillDate': 0, 'avgPrice': '0.00000', 'origQty': '0.007', 'clientOrderId': 'qGSNIOF1CpEmUolbF1P16', 'positionSide': 'BOTH', 'cumQty': '0.000', 'updateTime': 1749622439302, 'type': 'MARKET', 'reduceOnly': False, 'price': '0.00', 'cumQuote': '0.00000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}

# %%
# Get open orders
rsp = await pcli.get_um_open_orders("LUNA2USDT")
pprint(rsp)
# Out:
# []

# %%
# Cancel open orders
rsp = await pcli.cancel_um_order("COWUSDT", clientOid="tuNwX4olnc8C1cHn69shOyJ30mDPphMe")
pprint(rsp)
# Out:
# {'avgPrice': '0',
#  'clientOrderId': 'tuNwX4olnc8C1cHn69shOyJ30mDPphMe',
#  'cumQty': '0',
#  'cumQuote': '0.0000000',
#  'executedQty': '0',
#  'goodTillDate': 0,
#  'orderId': 187626710,
#  'origQty': '63',
#  'positionSide': 'BOTH',
#  'price': '0.3772000',
#  'priceMatch': 'NONE',
#  'reduceOnly': False,
#  'selfTradePreventionMode': 'NONE',
#  'side': 'BUY',
#  'status': 'CANCELED',
#  'symbol': 'COWUSDT',
#  'timeInForce': 'GTX',
#  'type': 'LIMIT',
#  'updateTime': 1737046590953}

# %%
# VWAP PM UM positions, Use with CAUTION!!!

_use_with_caution = False
_n_orders = 50
_qty = 20

if _use_with_caution:
    for i in range(_n_orders):
        rsp = await pcli.place_um_order(
            symbol="OMUSDT",
            side="BUY",
            type="MARKET",
            quantity=_qty,
        )
        print("[{}] order id = {}".format(i+1, rsp["orderId"]))
        await asyncio.sleep(1)
# Out:
# [1] order id = 4489242053
# [2] order id = 4489242662
# [3] order id = 4489243221
# [4] order id = 4489243768
# [5] order id = 4489244619
# [6] order id = 4489244964
# [7] order id = 4489245561
# [8] order id = 4489246119
# [9] order id = 4489246737
# [10] order id = 4489247006
# [11] order id = 4489247657
# [12] order id = 4489248083
# [13] order id = 4489248546
# [14] order id = 4489248742
# [15] order id = 4489249309
# [16] order id = 4489249882
# [17] order id = 4489250173
# [18] order id = 4489250644
# [19] order id = 4489251296
# [20] order id = 4489252115
# [21] order id = 4489252664
# [22] order id = 4489253147
# [23] order id = 4489254304
# [24] order id = 4489255046
# [25] order id = 4489255843
# [26] order id = 4489256612
# [27] order id = 4489257041
# [28] order id = 4489257582
# [29] order id = 4489258520
# [30] order id = 4489259640
# [31] order id = 4489260232
# [32] order id = 4489260695
# [33] order id = 4489261130
# [34] order id = 4489261790
# [35] order id = 4489262328
# [36] order id = 4489263115
# [37] order id = 4489263775
# [38] order id = 4489264280
# [39] order id = 4489265138
# [40] order id = 4489265490
# [41] order id = 4489266405
# [42] order id = 4489266653
# [43] order id = 4489267289
# [44] order id = 4489267811
# [45] order id = 4489268547
# [46] order id = 4489268923
# [47] order id = 4489269493
# [48] order id = 4489270057
# [49] order id = 4489270551
# [50] order id = 4489271091

# %% [markdown]
# # VWAP 对冲平仓

# %%
_use_with_caution = True
meta_symbol = "CHEEMS_USDT"
total_meta_qty = 18112601000
order_meta_qty = 72450000
order_cnt = total_meta_qty // order_meta_qty
actual_qty = order_meta_qty * order_cnt

sp_inst = inst_mngr.get_inst_by_meta_symbol(Exchange.BINANCE, InstType.SP, meta_symbol)
lps_inst = inst_mngr.get_inst_by_meta_symbol(Exchange.BINANCE, InstType.LPS, meta_symbol)

try:
    if order_meta_qty % sp_inst.price_multiplier == 0:
        sp_order_qty = int(order_meta_qty / sp_inst.price_multiplier)
        assert sp_order_qty > sp_inst.min_order_size, "SP min order size mismatch!"
        sp_order_arg = {
            "symbol": sp_inst.exchange_symbol,
            "side": "SELL",
            "type": "MARKET",
            "quantity": str(sp_order_qty),
        }
    else:
        raise ValueError("Invalid Meta Qty for SP")
    if order_meta_qty % lps_inst.price_multiplier == 0:
        lps_order_qty = int(order_meta_qty / lps_inst.price_multiplier)
        assert lps_order_qty > lps_inst.min_order_size, "LPS min order size mismatch!"
        lps_order_arg = {
            "symbol": lps_inst.exchange_symbol,
            "side": "BUY",
            "type": "MARKET",
            "reduceOnly": True,
            "quantity": str(lps_order_qty),
        }
    else:
        raise ValueError("Invalid Meta Qty for LPS")
except Exception as e:
    _vwap_config_validated = False
    print("Validation Failed!")
    print(e)
else:
    _vwap_config_validated = True
    print("Validation Success!")
    print(
        "total_meta_qty={} order_meta_qty={} order_cnt={} actual_qty={}".format(
            total_meta_qty, order_meta_qty, order_cnt, order_meta_qty * order_cnt
        )
    )
    print("sp_order_arg={}".format(sp_order_arg))
    print("lps_order_arg={}".format(lps_order_arg))
# Out:
# Validation Success!
# total_meta_qty=18112601000 order_meta_qty=72450000 order_cnt=250 actual_qty=18112500000
# sp_order_arg={'symbol': '1000CHEEMSUSDT', 'side': 'SELL', 'type': 'MARKET', 'quantity': '72450'}
# lps_order_arg={'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'type': 'MARKET', 'reduceOnly': True, 'quantity': '72450'}

# %%
if _use_with_caution and _vwap_config_validated:
    for cnt in range(order_cnt):
        print(f"[{cnt+1}/{order_cnt}] SELL SP: {sp_order_qty} {sp_inst.exchange_symbol}")
        sp_rsp = await pcli.place_margin_order(**sp_order_arg)
        print(sp_rsp)

        print(f"[{cnt+1}/{order_cnt}] BUY LPS: {lps_order_qty} {lps_inst.exchange_symbol}")
        lps_rsp = await pcli.place_um_order(**lps_order_arg)
        print(lps_rsp)

        _sleep = random.random() * 1 + 1
        print(f"sleep {_sleep:.2f}s")
        await asyncio.sleep(_sleep)
# Out:
# [1/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'Cr5ldGxGc1INoe9ZX1d298', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00001746', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '21141.00'}, {'commission': '0.00004239', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '51309.00'}], 'orderId': 121816285, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625646655, 'type': 'MARKET'}
# [1/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168412, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'G1lGFdvJACfVp0JTZI0783', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625646671, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.70s
# [2/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'uPD3WBG0PzJaOkIJnJX343', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005986', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '72450.00'}], 'orderId': 121816328, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625648393, 'type': 'MARKET'}
# [2/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168439, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'R2IB79uxkCn5QBvEIzD110', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625648418, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.55s
# [3/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'PXimXjBgKjiumjUDUKW979', 'cummulativeQuoteQty': '102.86418300', 'executedQty': '72450.00', 'fills': [{'commission': '0.00003611', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '43679.00'}, {'commission': '0.00001153', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '13954.00'}, {'commission': '0.00001224', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '14817.00'}], 'orderId': 121816393, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625649993, 'type': 'MARKET'}
# [3/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168485, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'qTVePcU7ln77CIHpQ5B122', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625650008, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.29s
# [4/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'jnHRY3eacD7OHDhlW10552', 'cummulativeQuoteQty': '102.83778400', 'executedQty': '72450.00', 'fills': [{'commission': '0.00001340', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '16210.00'}, {'commission': '0.00000621', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '7512.00'}, {'commission': '0.00000621', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '7512.00'}, {'commission': '0.00003405', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '41216.00'}], 'orderId': 121816457, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625651327, 'type': 'MARKET'}
# [4/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168585, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'tC5lCWupiJsYBOS1ygp188', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625651352, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.32s
# [5/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'xKAWEKmIDpzQaWQztuf808', 'cummulativeQuoteQty': '102.87900000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005991', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '72450.00'}], 'orderId': 121816520, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625652697, 'type': 'MARKET'}
# [5/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168610, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': '0V33icpHxALansw76ih842', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625652712, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.38s
# [6/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'k7OD3d0cqs5rZtxwrFe126', 'cummulativeQuoteQty': '102.87900000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005991', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '72450.00'}], 'orderId': 121816566, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625654115, 'type': 'MARKET'}
# [6/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168644, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'G9vkbfJzmC1FtnYEO8g895', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625654138, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.26s
# [7/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': '0KgE9fGZRSyHmPnzfCJ758', 'cummulativeQuoteQty': '102.87900000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005991', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '72450.00'}], 'orderId': 121816623, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625655445, 'type': 'MARKET'}
# [7/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168663, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'pcyHEJ19X53dZXIYJlQ121', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625655462, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.22s
# [8/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'zUWq0th7g8XQQ9NUG8W36', 'cummulativeQuoteQty': '102.87900000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005991', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '72450.00'}], 'orderId': 121816652, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625656706, 'type': 'MARKET'}
# [8/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168694, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'l6VY0RgRcP32eCxh87S247', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625656722, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.66s
# [9/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'CGyl4XkIxL9AsS8WzKF156', 'cummulativeQuoteQty': '102.87900000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00003529', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '42683.00'}, {'commission': '0.00001505', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '18206.00'}, {'commission': '0.00000955', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '11561.00'}], 'orderId': 121816657, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625658403, 'type': 'MARKET'}
# [9/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168706, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'dmsEZ7Ao6FVu2SOBUik53', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625658416, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.19s
# [10/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'kDvoglLF3qnG9KblX4p935', 'cummulativeQuoteQty': '102.87900000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00004867', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '58862.00'}, {'commission': '0.00001102', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '13339.00'}, {'commission': '0.00000020', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '249.00'}], 'orderId': 121816752, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625659637, 'type': 'MARKET'}
# [10/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168771, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'ZdMrUaRLCyLSqm0yHYt259', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625659654, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.67s
# [11/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'kdQCcago5cbRwwDFish836', 'cummulativeQuoteQty': '102.87900000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005802', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '70174.00'}, {'commission': '0.00000187', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '2276.00'}], 'orderId': 121816869, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625661351, 'type': 'MARKET'}
# [11/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168800, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'pI2gJNc3wPONw7a3J5t162', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625661366, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.15s
# [12/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': '1nszTuJ5XZhEmlCaiXC741', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005986', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '72450.00'}], 'orderId': 121816998, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625662541, 'type': 'MARKET'}
# [12/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168904, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'fK3gonupH4fuSLpvHNx800', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625662563, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.88s
# [13/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'J1dprIrZH8OLpR7fQCg25', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00002274', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '27520.00'}, {'commission': '0.00003712', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '44930.00'}], 'orderId': 121817047, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625664465, 'type': 'MARKET'}
# [13/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840168993, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'N9DvG07ZDXBZdBuAsh3909', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625664479, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.56s
# [14/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'PgrO0nfWndnxnoKU5d6821', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005986', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '72450.00'}], 'orderId': 121817063, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625666066, 'type': 'MARKET'}
# [14/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169051, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'TWPDq6Cmxq5cI04Cyke191', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625666081, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.43s
# [15/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'oqFaVEzrWAOhPI91zSk819', 'cummulativeQuoteQty': '102.83413000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00002280', 'commissionAsset': 'BNB', 'price': '0.00142000', 'qty': '27580.00'}, {'commission': '0.00001941', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '23492.00'}, {'commission': '0.00001766', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '21378.00'}], 'orderId': 121817076, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625667536, 'type': 'MARKET'}
# [15/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169101, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'cDcU83c3b0jM98pkSTg95', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625667551, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.71s
# [16/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'o8j0Jv4q5jsu4S8xzVw6', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00000573', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '6943.00'}, {'commission': '0.00005412', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '65507.00'}], 'orderId': 121817154, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625669286, 'type': 'MARKET'}
# [16/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169115, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'Up0IuiKIMRZopa6j42Z1', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625669301, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.07s
# [17/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'cf1fQpKstAYXmLUnvhS853', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005986', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '72450.00'}], 'orderId': 121817159, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625670401, 'type': 'MARKET'}
# [17/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169140, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'IceYh8T9TZyhzwvAWaa137', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625670417, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.37s
# [18/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'yUUSHMhemBwn9hkGk5a15', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005986', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '72450.00'}], 'orderId': 121817162, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625671812, 'type': 'MARKET'}
# [18/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169149, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'uY6woLjsG4jbUgfU9t586', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625671827, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.10s
# [19/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'nYcnlHKxbwXpKDK7Hcm728', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005986', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '72450.00'}], 'orderId': 121817166, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625672953, 'type': 'MARKET'}
# [19/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169159, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'PaLGeUzQKZcdUFx3pt1921', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625672967, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.45s
# [20/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'uZLchvGaJsGyqyrOXMS252', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00004100', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '49626.00'}, {'commission': '0.00001885', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '22824.00'}], 'orderId': 121817172, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625674443, 'type': 'MARKET'}
# [20/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169169, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'ePEnoUQH4r2tswHget4127', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625674463, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.09s
# [21/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'wxNMjyJDojDJstKfzIH291', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005986', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '72450.00'}], 'orderId': 121817178, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625675589, 'type': 'MARKET'}
# [21/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169175, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'hSxnsWTXfXjYk5SQjXG82', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625675603, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.84s
# [22/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'yKezVXTP0ArvOAcKzmu352', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005986', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '72450.00'}], 'orderId': 121817186, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625677470, 'type': 'MARKET'}
# [22/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169187, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'plSx7c1dUGWEG2n4WCv711', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625677485, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.92s
# [23/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'z2OiPbgKxOzdMlliyh260', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00001368', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '16571.00'}, {'commission': '0.00004617', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '55879.00'}], 'orderId': 121817197, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625679425, 'type': 'MARKET'}
# [23/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169209, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'JC3x1DAoXcJd9S1AzLp703', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625679440, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.00s
# [24/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': '7ktZs8PW5wF2uTg9E5D580', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005986', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '72450.00'}], 'orderId': 121817203, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625680473, 'type': 'MARKET'}
# [24/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169223, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': '6p2S702FOobPsgaEQah447', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625680490, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.92s
# [25/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'RB1rnlCTkYwD4iMadvB991', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00003979', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '48164.00'}, {'commission': '0.00002006', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '24286.00'}], 'orderId': 121817224, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625682436, 'type': 'MARKET'}
# [25/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169238, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'mRy38W65S2508qc3s9P320', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625682450, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.66s
# [26/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'MzDdkEa25ymjO88Eim015', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00003816', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '46186.00'}, {'commission': '0.00002169', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '26264.00'}], 'orderId': 121817229, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625684145, 'type': 'MARKET'}
# [26/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169247, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'CXttLE4yc7E9nYKWJSF111', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625684160, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.86s
# [27/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'WnJPBhsmCo4hmqXvAx3650', 'cummulativeQuoteQty': '102.80655000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00003652', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '44208.00'}, {'commission': '0.00002333', 'commissionAsset': 'BNB', 'price': '0.00141900', 'qty': '28242.00'}], 'orderId': 121817249, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625686050, 'type': 'MARKET'}
# [27/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169296, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'K4D4zdq19cYtuhLsm3Z148', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625686065, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.93s
# [28/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'pgklUNCQgJipE23Ngoj588', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00000873', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '10580.00'}, {'commission': '0.00000873', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '10580.00'}, {'commission': '0.00000873', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '10580.00'}, {'commission': '0.00003361', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '40710.00'}], 'orderId': 121817432, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625688015, 'type': 'MARKET'}
# [28/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169570, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'iU0G5wz2EAerlCGthdg23', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625688030, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.61s
# [29/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'Bv9YgNV5yqjpVOQifmq294', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00002461', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '29812.00'}, {'commission': '0.00002056', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '24911.00'}, {'commission': '0.00001463', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '17727.00'}], 'orderId': 121817439, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625689668, 'type': 'MARKET'}
# [29/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169628, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': '0hYtY1SPrk0wnMVUC9F924', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625689685, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.62s
# [30/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'umDrKybCZSP8BnBGwLg156', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00001623', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '19672.00'}, {'commission': '0.00000648', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '7857.00'}, {'commission': '0.00000648', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '7857.00'}, {'commission': '0.00000648', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '7857.00'}, {'commission': '0.00002411', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '29207.00'}], 'orderId': 121817664, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625691339, 'type': 'MARKET'}
# [30/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169808, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'VjOsRhxdfjMw3Z1cQYA251', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625691359, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.60s
# [31/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'zV53RLPm9zJWCNxudH7603', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00000977', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '11838.00'}, {'commission': '0.00000977', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '11838.00'}, {'commission': '0.00000911', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '11040.00'}, {'commission': '0.00003115', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '37734.00'}], 'orderId': 121817745, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625693007, 'type': 'MARKET'}
# [31/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840169895, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'VSYPXp9VOp7nVV8q1O8152', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625693022, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.31s
# [32/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': '10PnJKioIJ8YrHTXCiY431', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00002707', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '32788.00'}, {'commission': '0.00002911', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '35261.00'}, {'commission': '0.00000363', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '4401.00'}], 'orderId': 121817834, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625694361, 'type': 'MARKET'}
# [32/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840170169, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'TQYRjQDC6pwlvesJZ6W116', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625694376, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.41s
# [33/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'wb9T0yxW9P28isgXBJ9294', 'cummulativeQuoteQty': '102.67434000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00000348', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '4230.00'}, {'commission': '0.00000348', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '4230.00'}, {'commission': '0.00000348', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '4230.00'}, {'commission': '0.00004931', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '59760.00'}], 'orderId': 121817841, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625695812, 'type': 'MARKET'}
# [33/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840170210, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': '8B1DScr71W0j5uGIppL113', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625695829, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.78s
# [34/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'c9PjMVahRrUmxi8zmKx290', 'cummulativeQuoteQty': '102.66165000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005978', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '72450.00'}], 'orderId': 121817908, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625697640, 'type': 'MARKET'}
# [34/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840170243, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'IY3TkEghnBfbvAxXTBT790', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625697655, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.08s
# [35/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'GB9EjB5nkMEdi2rfZqZ259', 'cummulativeQuoteQty': '102.66165000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00004188', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '50767.00'}, {'commission': '0.00000069', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '849.00'}, {'commission': '0.00000062', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '755.00'}, {'commission': '0.00000066', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '815.00'}, {'commission': '0.00000061', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '753.00'}, {'commission': '0.00000138', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '1688.00'}, {'commission': '0.00001387', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '16823.00'}], 'orderId': 121817926, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625698757, 'type': 'MARKET'}
# [35/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840170266, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'gtNONCq8H9uykKNS71P718', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625698774, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.36s
# [36/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'girUS6sOuEBwSSdZJHa672', 'cummulativeQuoteQty': '102.66165000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005981', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '72450.00'}], 'orderId': 121817938, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625700158, 'type': 'MARKET'}
# [36/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840170310, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'WqvHmpbXizaahokrII0213', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625700176, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.50s
# [37/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'Vecgzqw6ti4rMVHIxly316', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005826', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '70522.00'}, {'commission': '0.00000159', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '1928.00'}], 'orderId': 121818015, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625701697, 'type': 'MARKET'}
# [37/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840170351, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': '22wTx8CL9r6Q01zIqGq200', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625701712, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.90s
# [38/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'MxXD8IWtgAcg2jj7hSw207', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005667', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '68594.00'}, {'commission': '0.00000318', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '3856.00'}], 'orderId': 121818022, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625703645, 'type': 'MARKET'}
# [38/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840170377, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 't7xaasOqJEpx7F6wSkK374', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625703663, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.78s
# [39/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': '2TZrOwRcmkRMRqSIyoi279', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00001019', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '12339.00'}, {'commission': '0.00001019', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '12339.00'}, {'commission': '0.00001019', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '12339.00'}, {'commission': '0.00002927', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '35433.00'}], 'orderId': 121818069, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625705473, 'type': 'MARKET'}
# [39/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840170401, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'aki6VBmJhWCKkT1W2mv962', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625705488, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.98s
# [40/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'Kp3tAK3QeUwB3CR4Qg7721', 'cummulativeQuoteQty': '102.71931500', 'executedQty': '72450.00', 'fills': [{'commission': '0.00001746', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '21150.00'}, {'commission': '0.00001746', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '21150.00'}, {'commission': '0.00001269', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '15365.00'}, {'commission': '0.00001220', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '14785.00'}], 'orderId': 121818083, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625707496, 'type': 'MARKET'}
# [40/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840170431, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'MApc6IWb7hAkqdoISK4244', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625707511, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.95s
# [41/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'Q1Z6vKlqi2buJ9Ixq6t964', 'cummulativeQuoteQty': '102.66165000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005981', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '72450.00'}], 'orderId': 121819174, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625709483, 'type': 'MARKET'}
# [41/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840170516, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'i9PL5ZGEkyLfY1tpDJu220', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625709498, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.36s
# [42/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'hx2KdGMkmjuj0edKcF1442', 'cummulativeQuoteQty': '102.66165000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005981', 'commissionAsset': 'BNB', 'price': '0.00141700', 'qty': '72450.00'}], 'orderId': 121819194, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625710887, 'type': 'MARKET'}
# [42/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840172062, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'l3aaFSTUACsHMQju0Nm942', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749625710904, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.03s
# [43/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'zdCr8Do6mxymlcasLAC161', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00000807', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '9773.00'}, {'commission': '0.00000807', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '9773.00'}, {'commission': '0.00004371', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '52904.00'}], 'orderId': 121819515, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749625711952, 'type': 'MARKET'}
# [43/250] BUY LPS: 72450 1000CHEEMSUSDT
# ...
# [237/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840187923, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'HbghIOyCcruKAjl1QDU951', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626012856, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.98s
# [238/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'tNZ0jUNYC0lwc0KBeFl115', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005315', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '64438.00'}, {'commission': '0.00000334', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '4056.00'}, {'commission': '0.00000326', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '3956.00'}], 'orderId': 121830346, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626014857, 'type': 'MARKET'}
# [238/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188006, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': '2t1xPxZ1eMmrbaeuyPo331', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626014873, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.64s
# [239/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'bqVAcXVoPrHhDFf8uZB309', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005490', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '66566.00'}, {'commission': '0.00000485', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '5884.00'}], 'orderId': 121830388, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626016536, 'type': 'MARKET'}
# [239/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188071, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'YaxaHlSlUvDcjzpKBh0781', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626016553, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.19s
# [240/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': '1m9XO8r3tdvPWN47Tkv815', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005331', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '64638.00'}, {'commission': '0.00000644', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '7812.00'}], 'orderId': 121830410, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626017767, 'type': 'MARKET'}
# [240/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188088, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'UsWvzKnzbB6nCYDEUkC181', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626017785, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.20s
# [241/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'EIgrVhm4RtZIdTmN69Q405', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005172', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '62710.00'}, {'commission': '0.00000803', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '9740.00'}], 'orderId': 121830447, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626019005, 'type': 'MARKET'}
# [241/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188142, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'PhPDbSLZgJvOELUdjEZ686', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626019021, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.94s
# [242/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'Har0HLB9CoLNahzAUyH674', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00000334', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '4056.00'}, {'commission': '0.00000267', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '3241.00'}, {'commission': '0.00002064', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '25030.00'}, {'commission': '0.00000333', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '4055.00'}, {'commission': '0.00002908', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '35261.00'}, {'commission': '0.00000066', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '807.00'}], 'orderId': 121830513, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626020987, 'type': 'MARKET'}
# [242/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188220, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'X9a0wxE8MqzWRSKnIWt114', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626021002, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.29s
# [243/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'QcQDPPMaukdwtrWVDoT154', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005750', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '69715.00'}, {'commission': '0.00000225', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '2735.00'}], 'orderId': 121830550, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626022313, 'type': 'MARKET'}
# [243/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188283, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'qtuScmw4FI0SdfgUvB3984', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626022327, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.20s
# [244/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'TveVNL7R9x9CVjUzq3Y609', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00000333', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '4055.00'}, {'commission': '0.00001053', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '12773.00'}, {'commission': '0.00004587', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '55622.00'}], 'orderId': 121830680, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626023552, 'type': 'MARKET'}
# [244/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188310, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'lIifkp6ljo2v3PSfKaN185', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626023571, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.16s
# [245/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'VH7ojTJ7ZPzoeUSezP3403', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00001228', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '14900.00'}, {'commission': '0.00004746', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '57550.00'}], 'orderId': 121830718, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626024749, 'type': 'MARKET'}
# [245/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188319, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'LlGYTdlh6AgzJWNlYVh986', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626024765, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.54s
# [246/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'VZuteWotsnkJpMlG2Vj861', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00001069', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '12972.00'}, {'commission': '0.00004905', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '59478.00'}], 'orderId': 121830794, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626026332, 'type': 'MARKET'}
# [246/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188377, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'Xh7lCRovuTZT5ajHxHh48', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626026354, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.14s
# [247/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'nnZZ2IRtMyAposLIlg0736', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00000910', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '11044.00'}, {'commission': '0.00005064', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '61406.00'}], 'orderId': 121830876, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626027532, 'type': 'MARKET'}
# [247/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188429, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'CV4r1YSFeaQgypRI0cL162', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626027557, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.02s
# [248/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'C2dyunfhdEreUJI1ckR217', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00000751', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '9116.00'}, {'commission': '0.00002908', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '35261.00'}, {'commission': '0.00002315', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '28073.00'}], 'orderId': 121831196, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626028606, 'type': 'MARKET'}
# [248/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188541, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'duWduxaDhVt4g1RBgM1781', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626028624, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.21s
# [249/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': 'CrRVvOFaWabYXFz0cTh537', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00001017', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '12333.00'}, {'commission': '0.00004958', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '60117.00'}], 'orderId': 121831227, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626029865, 'type': 'MARKET'}
# [249/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188582, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': 'GHzguM2RlkwJAskhDmA24', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626029882, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.25s
# [250/250] SELL SP: 72450 1000CHEEMSUSDT
# {'clientOrderId': '3HzFea9Lnl7iFm0A0vr197', 'cummulativeQuoteQty': '102.73410000', 'executedQty': '72450.00', 'fills': [{'commission': '0.00005817', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '70522.00'}, {'commission': '0.00000159', 'commissionAsset': 'BNB', 'price': '0.00141800', 'qty': '1928.00'}], 'orderId': 121831274, 'origQty': '72450.00', 'price': '0.00000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'side': 'SELL', 'status': 'FILLED', 'symbol': '1000CHEEMSUSDT', 'timeInForce': 'GTC', 'transactTime': 1749626031155, 'type': 'MARKET'}
# [250/250] BUY LPS: 72450 1000CHEEMSUSDT
# {'symbol': '1000CHEEMSUSDT', 'side': 'BUY', 'executedQty': '0', 'orderId': 840188640, 'goodTillDate': 0, 'avgPrice': '0.0000000', 'origQty': '72450', 'clientOrderId': '0gtq0fuObNg6fx8MIMb93', 'positionSide': 'BOTH', 'cumQty': '0', 'updateTime': 1749626031171, 'type': 'MARKET', 'reduceOnly': True, 'price': '0.0000000', 'cumQuote': '0.0000000', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'timeInForce': 'GTC', 'status': 'NEW', 'priceMatch': 'NONE'}
# sleep 1.37s

# %% [markdown]
# # 跨子账户转账

# %%
jw_acct_email_map = {
    "4abnjwarb01": "chrix001_virtual@7zozg3e3noemail.com",
    "4abnjwarb02": "chrix002_virtual@exziukkmnoemail.com",
    "4abnjwarb03": "chrix003_virtual@ppm6h3zmnoemail.com",
}

from_acct = "4abnjwarb02"
to_acct = "4abnjwarb01"

trsf_scli: BinanceSpotRestClient = get_rest_client(Exchange.BINANCE, InstType.SP, account=from_acct)
trsf_pcli: BinanceUnifiedRestClient = get_rest_client(Exchange.BINANCEUNIFIED, InstType.SP, account=from_acct)

# %%
asset = "USDT"

trsf_p_bal = await trsf_pcli.get_balance()
trsf_p_bal_df = pd.DataFrame(trsf_p_bal).set_index("asset")
trsf_p_bal_df.loc[asset]
# Out:
# totalWalletBalance               0.0
# crossMarginAsset                 0.0
# crossMarginBorrowed              0.0
# crossMarginFree                  0.0
# crossMarginInterest              0.0
# crossMarginLocked                0.0
# umWalletBalance                  0.0
# umUnrealizedPNL                  0.0
# cmWalletBalance                  0.0
# cmUnrealizedPNL                  0.0
# updateTime             1749625034948
# negativeBalance                  0.0
# Name: USDT, dtype: object

# %%
resp = await trsf_scli.get_spot_account()
s_bal_df = pd.DataFrame(resp["balances"]).set_index("asset")
s_bal_df.free = s_bal_df.free.astype(float)
s_bal_df.loc[asset]
# Out:
# free     0.0000000000
# locked     0.00000000
# Name: USDT, dtype: object

# %%
_use_with_caution = True
if _use_with_caution:
    trsf_resp = await trsf_scli.sapi_sub_account_transfer_sub2sub(
        toEmail=jw_acct_email_map[to_acct],
        asset=asset,
        amount=Decimal(s_bal_df.loc[asset].free),
    )
    pprint(trsf_resp)
# Out:
# {'txnId': 268207749849}
